# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhila1810/ML-ASS-03/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=186mGJmdEocFGHBHH4zq10seZ7_O9xqmd)
#
#
#
# File available at https://github.com/Nikhila1810/ML-ASS-03
#
#
#
# ![alt text](https://drive.google.com/uc?id=1a0rxxwdDlsleh3GgyMiJddlBmGBBRB-T)
#
#
#
# 1.	INTRODUCTION
#
# 1.1	PROBLEM DEFINITION
#
# Every individual today spends most of their time in social media for updating status, checking the status of other people and following the public figures, brands organizations etc. Some of the top strong platforms of the social media are Facebook, Instagram, and Twitter. Not only the common people but also the organizations, public figures including the politicians, film actors& actress, elections and even the government organizations have chosen these platforms to promote their day to day activities.  Even many organizations assume that the direct public opinion can be heard through these platforms correctly without any manipulation of the information in the middle. Do you really understand how powerful these platforms are now? So, many organizations analyse the data which is collected from these sites for the betterment of the tools for their organizations. One of the questions which arise in the mind is. Is this ethical? Are we acknowledging the people regarding this before collecting the data or at least while their status updation!!
#
# The most common mobile phone that everyone uses these days is Apple. Personally, I use the iPhone. I had various doubts while purchasing it because some of my friends said iPhone XS is good and some say iPhone X works very well when compared to XS and some say XR. As all the three models are released at a time, I faced lots of confusion while purchasing. I hope many of us have the same problem while purchasing. So, in order to know the voice of the public opinion and as part of the assignment, I consider Apple - iPhone brand and apply the sentiment analysis for the public opinion and finally analyse the risks.
#
# Sentiment analysis can be defined as the technique which helps to develop the organization or the brand by collecting the social sentiments of the people from the social media platforms. Thus, the problem statement for our work could be the sentiment analysis on the iPhone X, XS from the twitter based on the tweets with hashtags #iPhone X #iPhone XS #apple etc.
#
# In order to solve our statement in few steps.
#
# 1.	Collection of data from the Twitter.
#
# 2.	Data cleaning – Main aim is to collect only useful data
#
# 3.	Sentiment analysis
#
# 4.	Implementation of algorithms based on sentiment – positive, neutral and negative.
#
# 1.1.1	SIGNIFICANCE
#
# This sentiment analysis has got lots of significance as this is used by the brand to improve their product and its quality based on the public opinion. This improvement will further enhance their brand name and return in more capital to the brand.
#
# 1.2	DATA MINING
#
# ![alt text](https://drive.google.com/uc?id=1uvyR1KYtzxzuY4kyy-DYL8T_3bRqT-xO)
#
# Figure: Phases of data analysis
#
# The above figure explains the overall workflow that has to adopted to solve the problem.
#
#
# 2.	EXPLORATION
#
# ![alt text](https://drive.google.com/uc?id=1GHc4vidRhxFiVRBisSsFnxtGZrJHW4Qq)
#
# Figure: Sentiment Analysis Exploration
#
# The above figure depicts the steps to that has to be adopted for sentiment analysis of the tweets in the document.
#
# 2.1	PROGRAMMING LANGUAGE
#
# I have used R programming language. This is an open source mainly used to statistical analysis of the data. I have used the followed packages for my work.
#
#
# ![alt text](https://drive.google.com/uc?id=1R1sBDAyeZqOYrlAcljiOdmYeMOcDcHpR)
#
#
# 2.2	TWITTER APPLICATION CREATION
#
# In order to collect the real time data of the tweets, we need to create an application in the twitter. Following steps will explain you about the creating from the development platform of the twitter.
#
# 1.	Login to your twitter account by https://developer.twitter.com
#
# 2.	Select App from the drop-down list and create a new application by selecting exploring API option.
#
# 3.	After successful app creation you will be able to see the token, secret token, consumer key and the secret consumer key.
#
# 4.	Authentication has to be done from the R console by which we will get an OTP/code to the Twitter application.
#
# ![alt text](https://drive.google.com/uc?id=1e5NsGhGP35wgRHwQVUoIcnKWVO_51P6O)
# Figure Twitter App creation
#
#
# ![alt text](https://drive.google.com/uc?id=1xLm7wlvuaGmd-tU2h56h6rMDRXWhxBsC)
# Figure keys and tokens
#
# ![alt text](https://drive.google.com/uc?id=1ofvBvrbUUez6c1oLwXaE3ihvEThTCi1l)
# Figure R console Code
#
# After authentication, true message will be displayed on the console. This will confirm from both the platforms.
#
# 2.3	DATA EXPLORATION
#
# Next step to explore the data i.e. tweets with the hashtag #iPhoneX, #iPhone XS. After the extraction of the data we will use this dataset as testing dataset. Using Search twitter, we can download and save the tweets. These are in a data frame which is to be converted to.csv file.
#
# ![alt text](https://drive.google.com/uc?id=1kjw7dp5V3EVQa6Mrq0VAyamx9FXKxyza)
#
# We also need a training set, for this I have used one of the datasets available at Kaggle https://www.kaggle.com/c/twitter-sentiment-analysis2/discussion. Both the datasets have common fields i.e. tweets id, sentiments etc. tweets are to be classified as per positive, negative and neutral. The dataset extracted from the twitter has 17 columns and 5000 rows. Both the datasets i.e. training, and testing columns are described below.
#
# •	Text –Tweet which has updated by the user.
#
# •	Favourited – If the tweet has been liked or commented by the other users of the twitter.
#
# •	favouriteCount – displays how many times it’s been liked.
#
# •	replytoSN – name of the user who has commented on the post.
#
# •	created – displays date and the time of the tweet creation for the first time.
#
# •	truncated – displays information about the retweet and its length. If it’s true, then it’s truncated if no not truncated.
#
# •	replytoSID – Id of the user who is replying to the tweet.
#
# •	Id – unique id of the tweet.
#
# •	replytoUID – It’s the original user ID.
#
# •	statusSource – Source user who is responsible for tweeting.
#
# •	ScreenName – Reference username.
#
# •	Retweetcount – count of the retweet.
#
# •	isRetweet – indicates if the Retweet doesn’t happen.
#
# •	retweeted – check with the client verification.
#
# •	longitude – location of the tweet.
#
# •	latitude - location of the tweet.
#
#
# 2.3	DATA CLEANING
#
# Dataset is in raw form, we have lots of columns from the tweets, out of these we will use only the fields which we need to solve our problem and thus eliminate the remaining. We also have various emotions symbols, punctations etc, all these are to be pre-processed.
#
# ![alt text](https://drive.google.com/uc?id=10vkbtGEPCSQFnnxHLkYpY8MffFePHsFI)
# Figure Data pre-processing workflow
#
# 2.3.1	TWEET CLEANING
#
# Complete dataset has to cleaned by using tm package.
#
# 1.	Convert either the whole dataset tweets into lower case or the uppercase letters.
#
# 2.	Remove punctuations, emotions etc.
#
# 3.	Remove URL.
#
# 4.	Remove stop words and correction of spellings.
#
# 5.	Stemming and lemmatization
#
# R language is case -sensitive, which means Tweet is different from tweet. So, for this I decided to convert whole document into lower case letters. Punctuations and other emotions are not necessary for solving the problem. So, we shall remove them also. Stop words are the words from the articles, verbs and the qualifiers in the tm package. these are not necessary for us. white space can be removed by the stripwhitespace function in the R language. Stemming and lemmatization i.e. stemming is a process of counting down the words with same origin and the lemmatization is a process of correcting the grammatical errors of same origin words. I used twitteR, SnowballC and the tm packages for this process.
#
#
# ![alt text](https://drive.google.com/uc?id=1m7JT0Fe3vnqP5AIS1PXqyWByRXpfmf8z)
#
# Figure Code for converting tweets into lowercase letter, removing punctuations, emotions, URL, and also the stop words.
#
# ![alt text](https://drive.google.com/uc?id=1kHjZ7R_-UqEo7HKjvAaFykn3O3gSiDt0)
#
# Figure Code for removing the hashtags and URL.
#
# ![alt text](https://drive.google.com/uc?id=1oLaO58-9rLqXeIHKXcH_92E5gznybjpi)
#
# Figure Code for Stemming and lemmatization
#
# ![alt text](https://drive.google.com/uc?id=1tRrpKSQOsTYvwUns9dFDtPqa05PP-4p8)
#
# Figure Count of unique words found in tweets
#
# The bar graph explains about the unique stop words that are found. They have to be removed as they are just used to form a meaningful sentence. tidy_text package is used to remove all the stop words and anti_join to remove all stop words from the data analysis.
#
# ![alt text](https://drive.google.com/uc?id=1A717UN6fvY0j1VaDU8u9T2iaWAecr9ID)
#
# Figure Count of Stop word removed from the unique words in the tweet
#
# ** iPhone is the most used term to tweet by most of the users and even this has to be removed for the analysis purpose.
#
# TERM DOCUMENT MATRIX
#
# Term document, all the letters are in the form of 0 and 1 in rows and columns. It’s in a matrix format. If the same word repeats, then the count of the word increments by 1 and so on.
#
# ![alt text](https://drive.google.com/uc?id=1yv3kroZKaVvwKZnMuvsvOzm4B6N0otuM)
# Figure Term Document Matrix representation
#
# ![alt text](https://drive.google.com/uc?id=1Y0SWkdh5LE_r7SWC0awWZIgxXsTArivZ)
# Figure Term Document Matrix Code
#
# 2.4.2       TWEET PARSING
#
# After data cleaning, we need to transform the data i.e. tweet parsing, this is done in the following sequential steps.
#
# •	Extraction of hashtags
#
# Hashtag can be defined as the updating the sentence or voice of the personal idea with the symbol “#” before the start of each sentence. So, in the assignment I extracted the tweets with hashtag #iPhone X and #iPhone XS.
#
#
# ![alt text](https://drive.google.com/uc?id=1xnY504qEDDiQh3J1ATG2M3vLByoEnDmL)
#
# Figure Most used Hashtags
#
# •	Removal of indicators of the sentence
# For clearer and betterment of the idea, I removed the indicators or the words with “but, so, because, although” etc.
#
# 2.4	SENTIMENT ANALYSIS
#
# Sentiment analysis can be defined as the technique which helps to develop the organization or the brand by collecting the social sentiments of the people from the social media platforms. It is a process of analysing the tweets collected from twitter and classified into positive, negative and neutral. These tweets are then converted and modelled using the various algorithm and then compared with the previous trends or the data of a particular brand in an organization. Strings are converted by using plyr and stringr packages. We make three separate lists based on the user tweets.
#
#
# ![alt text](https://drive.google.com/uc?id=14IpQX_lCg8SM-ZXi3cckwDnTqNC6d8Jt)
#
# Figure Sentiment analysis Code
#
# ![alt text](https://drive.google.com/uc?id=1nIfC0bM-_Uh9Be3BpL1hMpzVPbRa3vCi)
#
# Figure Bar plot Code
#
# ![alt text](https://drive.google.com/uc?id=1d9EJ6mPrPd9CYcqobUkJSl3k8XED1e3-)
#
# Output of the Bar Plot
#
# 2.5	POLARITY
#
#
# ![alt text](https://drive.google.com/uc?id=1338huZy_Cr9HiUdnv4p5YrSbAYhOfOG3)
#
# Figure Output of the polarity
#
# From the output, we can clearly understand that the positive sentiments are more negative sentiments. Positive is represented by 0 and negative by 1. 0 is denser when compared with 1. That means most of the tweets are happy.
#
#
# ![alt text](https://drive.google.com/uc?id=1gjbYzNf9FR4-TvMrHDHoTRNiE7fAGxT4)
#
# Figure SocioViz tool: Scatter plot of the both the sentiments
#
# 2.6	WORD CLOUD
#
# It’s a visual representation of textual data. This represents maximum used words by the users in their tweets.  This visualization is achieved by the Wordcloud package.
#
# ![alt text](https://drive.google.com/uc?id=1bimng0TFGulXIP2VSnG_5L7eJOTMmNPj)
#
# Figure Wordcloud Code
#
# ![alt text](https://drive.google.com/uc?id=1zGgZRLVZMf4Pw5i02m2MbrW9eF7EFEUD)
#
# Figure Wordcloud Output
#
# 3.	METHODOLOGY
#
# 3.1	BIGRAM MODEL
#
# In natural language processing, feature selection plays a vital role. As the tweets from the user will not understandable by the system, they should be converted to 0's and 1's. So, all the emotions, URL, and other stop words have to be converted using various pre-processing techniques. The tweets will be then breaking down into individual words.
#
# ![alt text](https://drive.google.com/uc?id=1i1bevNjufHmxMm9PRBh2amOPjorZqqgk)
#
# Figure bigram model code
#
#
# ![alt text](https://drive.google.com/uc?id=1w_XTOq4cwBRurPE4ZuumZUntuBHFQFgF)
#
# Figure Output
#
# ![alt text](https://drive.google.com/uc?id=1OuCtkSNkZJbIEhxMikaUxE1qOtFzTAu8)
#
# Figure Bigram model
#
# 3.2	N GRAM MODEL
#
# In this model, each individual word is considered as a unique token. For example, DO is consider as a single gram token.
#
# ![alt text](https://drive.google.com/uc?id=1_GiPXdHdX6MiwhMHTQAnqwsvV91PLQbE)
#
# Figure Most common used words
#
# ![alt text](https://drive.google.com/uc?id=1Na2C7961w7vgq3wn7muWbQUctaxLDpfl)
#
# Figure Word Network
#
#
# ![alt text](https://drive.google.com/uc?id=1lWPvS9B7YuIV6Ye7JRDj8hrVBbHv4NvA)
#
# Figure Word Network Code
#
#
# ![alt text](https://drive.google.com/uc?id=15A_bP6sdLhMpHRXRISaKcWHEpY48iTCl)
#
# Figure Word Network through R language
#
#
# 3.3	CLASSIFIER
#
#  I have implemented Naïve Bayes, KNN, Random Forest and Neural networks and also compared the results of them with each other and then analysed the best classifier for the sentiment analysis of tweets.
#
# 1.	Naïve Bayes
#
# I implemented this for training dataset. Advantages of this classifier are
#
# •	Easy to interpret
#
# •	High prediction power
#
# •	Predicts the conditionality
#
# Equation of the Naïve Bayes is
#
# ![alt text](https://drive.google.com/uc?id=1K_5pSFA5rvHDycxAzJUR3f8WvXGGz3BX)
#
#
# Using Bayes, we can classify the tweets whether they are positive, negative or neutral.
#
# Equation of this is
#
# ![alt text](https://drive.google.com/uc?id=1K_kB8Hg7y08j3ASkdCOXMUFcEsY9RbZl)
#
#
# Naïve classifier assumes that each word is treated as independent word in the tweets. But this is wrong assumption. Equation of this is
#
# ![alt text](https://drive.google.com/uc?id=1AtUkPDbSBY5WblUsmPiOSen5cr10RFIf/)
#
# From the equation, the probability is
#
# •	P (“I”| Negative) – appearance of the “I” in negative reviews.
#
# •	P(negative) –words in negative reviews/ number of words consisting in the training dataset.
#
# •	P(“I”) –number of times I occurs in reviews / number of words consisting in the training dataset.
#
# Same process has to repeated for the calculation of the positive words. This probability decides the sentiments of the tweets made by the users.
#
# 2.	KNN Classifier
#
# KNN is termed as K-Nearest neighbor.
#
# Advantaged of this algorithm are
#
# •	easy to understand
#
# •	implementation is easy and effective
#
# •	One of the most effective tools in the analysis of sentiments.
#
# •	Data assumptions are possible through this algorithm.
#
# •	KNN is non-parametric
#
# •	non-Linear
#
#
# 3.	Random Forest
#
# This is used in the combination of various decision trees. In our work, I think this can’t be used because it produces the result of positive, if the majority of the tweets are positive. So, in practical implementation of this to our work is not feasible.
#
# 4.	Neural Networks
#
# This works on optimization algorithm. This is most effective in reducing the cost of the neural networks.
# ![alt text](https://drive.google.com/uc?id=1kaCrkdpunk6hp5TtRvzM_TynZmAd1E30)
#
# Figure Neural network
#
# These models are analyzed on Orange Tool. The training dataset is used to train the neural network and testing data is for the constant checking of the predictions.
#
# ![alt text](https://drive.google.com/uc?id=1gozRA3fDYfbBpVwmygzxZSQdG-W5D6d4)
#
# Figure Workflow diagram of KNN and the Naïve Bayes
#
# ![alt text](https://drive.google.com/uc?id=1BB-DB5xFdrprPs3Sl_UieuJSj7mmyMMG)
#
# Figure Workflow diagram of the Naïve Bayes and the Random Forest
#
# ![alt text](https://drive.google.com/uc?id=10mUkHYDouLsdCar4Jney96E-bFmFZvJu)
#
# Figure Workflow implementation of all the algorithms
#
# 4.EVALUATION
#
# So, after completing the data exploration, cleaning, pre-processing then comes the machine learning algorithms. Many algorithms are implemented on the tweets for the analyzation of the best suitable algorithm that would reduce the error rate to predict the output accurately.  Generally, we don't expect the algorithms to do mistakes. But sometime in the real world, they do mistakes too. So, we will calculate the confidence of each algorithm. This is done by F-score. The training dataset is classified into 10 folds, in which most of them around 8 or 9 are for the training dataset and the 1 is for the testing dataset. This complete methodology is known as holdout cross validation.
#
# The following models are evaluated:
#
# 1.	Naïve Bayes
#
# 2.	KNN
#
# 3.	Random Forest
#
# 4.	Neural networks
#
# Among all those KNN has highest accuracy rate which indicates that this is most suitable for sentiment analysis.
#
# ![alt text](https://drive.google.com/uc?id=1ZXFYCvnFMNpEqU4ITO3xqCd_l4q0EiEa)
#
# Figure Implementation of all the models
#
# ![alt text](https://drive.google.com/uc?id=1w4_MmcpW5aEn9WDS5e32NCguYqsC-vqZ)
#
# Figure KNN Classifier
#
# ![alt text](https://drive.google.com/uc?id=1KQk7dxgN3mqyNow8ibnAlojnIk-hLKtP)
#
# Figure ROC
#
# ROC curve indicates both the positive – sensitivity and the false positive – 1- specificity. This curve also indicates the KNN is the best classifier for the sentiment analysis of the tweets.
#
# 5.	CONCLUSION
#
# The purpose of the assignment is to perform sentiment analysis on the tweets collected by twitter. Sentiment analysis can be defined as the technique which helps to develop the organization or the brand by collecting the social sentiments of the people from the social media platforms. Thus, the problem statement for our work could be the sentiment analysis on the iPhone X, XS from the twitter based on the tweets with hashtags #iPhone X #iPhone XS #apple etc. We classified the tweets into negative, positive and neutral based on the online dictionary. We implemented four different classifiers i.e. Naive Bayes, KNN, Random Forest and Neural network out of which KNN gave the best results in terms of more accuracy. The ROC curve also suggests this. Most of the tweets from the users are positive which also indicates that they are happy with the product and the iPhone X is a successful phone. These kinds of analyses will improve the capital and also the brand name in the business market. This sentiment analyses is not limited to phones, we can perform on any real world things.
#
# 6.	ETHICAL
#
# Many organizations analyse the data which is collected from these sites for the betterment of the tools for their organizations. One of the questions which arise in the mind is. Is this ethical? Are we acknowledging the people regarding this before collecting the data or at least while their status updation!!
#
# Personally speaking, if the social media platform specifies that their tweets are collected for analyses purpose, then I think some sort ethical behaviour. But if they miss to mention, then its unethical.
#
# 7.	REFERENCE
#
# Anon, 2019, Arxiv.org. viewed 26 September 2019, <https://arxiv.org/pdf/1711.10377.pdf>.
